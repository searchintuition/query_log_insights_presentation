# %% [markdown]
# # Recipe #4:  Taste Profiles

# %% [markdown]
# For taste profiles, we need to index the following data-shape:
#
# (**user**, **query[]**, **document[]**)

# %%
import sys
# !conda install --yes --prefix {sys.prefix} elasticsearch jsonlines jsonpath-ng python-slugify
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import pandas
import json
from extract import extract, parse_json
from taste.transform import reshape, preload
from index import create_index, populate_index, query_index, index_mapping, query_template, peek, get

# %% [markdown]
# ## Source data

# %%
source = extract('./data/real_estate_queries.tsv')

# peek
source.head(5)
# Out:
#    user                                              query  \
# 0  1337           national real estate settlement services
# 1  1337           national real estate settlement services
# 2  1337  sunbury pennsylvania real estate settlement se...
# 3  1337                             integrated real estate
# 4  1337                             integrated real estate
#
#              timestamp  position                       document         state
# 0  2006-03-14 15:59:13       1.0         http://www.realtms.com           NaN
# 1  2006-03-14 15:59:13       7.0                http://dmoz.org           NaN
# 2  2006-03-14 16:06:28      14.0       http://pa.optimuslaw.com  pennsylvania
# 3  2006-03-27 14:52:29       1.0  http://www.integratedreal.com           NaN
# 4  2006-03-27 14:52:29       2.0         http://www.irisnet.net           NaN

# %% [markdown]
# ##  Transform to fit the recipe

# %%
reshaped = reshape(source)

# peek
reshaped.head(50)
# Out:
#      user                                              query  \
# 0     475  [real estates lookup in charlotte, real estate...
# 1     756  [chesapeake real estate assesser, virginia bea...
# 2    1133   [huntsville real estate, huntsville real estate]
# 3    1337  [national real estate settlement services, nat...
# 4    1338  [real estate chesapeake appreciation 2005, rea...
# 5    2470                       [harbor country real estate]
# 6    2761  [norco real estate, norco real estate, corona ...
# 7    3769                          [little rock real estate]
# 8    4781             [tucker group real estate and florida]
# 9    4945  [real estate courses, real estate courses, fis...
# 10   5070                               [powell real estate]
# 11   5826                  [illinois commercial real estate]
# 12   7764  [galveston beach opinions real estate, galvest...
# 13   9780  [hamilton montana real estate, hamilton montan...
# 14   9993  [nys real estate exam, www. real estate manage...
# 15  10008  [cape cod real estate.com, new hampshire me re...
# 16  10215  [real estate orlando florida, real estate orla...
# 17  11663  [real estate findlay ohio, rooney real estate ...
# 18  12653  [real estate for dummies, real estate for dumm...
# 19  13097                        [real estate home warranty]
# 20  13119  [what is a real estate agent suppose to do, wh...
# 21  13379  [real estate northern liberties philadelphia, ...
# 22  13577                                [mogen real estate]
# 23  14295              [potomac real estate coldwell banker]
# 24  15997      [luxury real estate, real estate port richey]
# 25  16790  [denver co real estate cherry creek, denver co...
# 26  18987                           [college of real estate]
# 27  19058               [meridian ms commercial real estate]
# 28  19166                         [ewa beach ha real estate]
# 29  19913         [bashore real estate, bashore real estate]
# 30  19975                  [blairsville georgia real estate]
# 31  20104   [sea pines real estate, savannah ga real estate]
# 32  20320  [real estate for sale saratoga new york, real ...
# 33  21901                  [dijon france real estate agents]
# 34  22304                   [carollo real estate of bayside]
# 35  22516  [real estate orange tip irvine calif 92604, re...
# 36  22698  [real estate pedley california, real estate pe...
# 37  24122                          [texas real estate agent]
# 38  24537                      [keller williams real estate]
# 39  25003               [mosley-flint school of real estate]
# 40  25804         [mcneary real estate, mcneary real estate]
# 41  27371                      [hampton country real estate]
# 42  27949  [texas instruments ba real real estate, texas ...
# 43  28538   [prudential real estate, prudential real estate]
# 44  28829           [keller real estate, keller real estate]
# 45  29720  [real estate irs withholding calculator califo...
# 46  30011  [real estate in rosemount mi, real estate in r...
# 47  30054                         [howard hanna real estate]
# 48  30996         [real estate classes near hillsborough nc]
# 49  34363  [real estate in covington la, real estate in c...
#
#                                              document
# 0   [http://meckcama.co.mecklenburg.nc.us, http://...
# 1   [http://www.chesapeake.va.us, http://www.vbgov...
# 2   [http://www.valleymls.com, http://www.valleyml...
# 3   [http://www.realtms.com, http://dmoz.org, http...
# 4   [http://realtytimes.com, http://realtytimes.co...
# 5                      [http://www.harborcountry.org]
# 6   [http://www.neighborhoodscout.com, http://www....
# 7                          [http://cityguide.aol.com]
# 8                        [http://www.bizjournals.com]
# 9   [http://www.online-education.net, http://www.u...
# 10                  [http://www.powellrealestate.com]
# 11                          [http://www.cityfeet.com]
# 12  [http://www.sellinggalveston.com, http://www.c...
# 13  [http://www.buybitterroot.com, http://www.nort...
# 14   [http://www.dos.state.ny.us, http://www.bls.gov]
# 15  [http://www.capecodrealestate.com, http://www....
# 16  [http://www.orlandosentinel.com, http://www.ho...
# 17  [http://www.realtor.com, http://www.idxvow.com...
# 18  [http://www.dummiesrealestate.com, http://www....
# 19                              [http://www.bhwc.com]
# 20  [http://www.realestateabc.com, http://www.real...
# 21  [http://philadelphia.craigslist.org, http://ww...
# 22                             [http://www.mogen.com]
# 23                          [http://www.board123.com]
# 24  [http://www.luxuryrealestate.com, http://newpo...
# 25  [http://denver.co.house.info, http://www.fulle...
# 26                         [http://www.smeal.psu.edu]
# 27                      [http://www.meridianstar.com]
# 28                          [http://www.hudclips.org]
# 29   [http://www.era.com, http://www.tomieraines.com]
# 30                          [http://www.homegain.com]
# 31  [http://www.seapinesrealestate.com, http://www...
# 32  [http://www.homes.com, http://www.geraldine.co...
# 33                   [http://www.french-property.com]
# 34                 [http://www.carollorealestate.com]
# 35  [http://valuecom.com, http://www.switchboard.c...
# 36  [http://www.lawrenceelliott.com, http://www.ci...
# 37                          [http://www.homegain.com]
# 38                                [http://www.kw.com]
# 39                         [http://realestateiii.com]
# 40  [http://www.mcnearyrealty.com, http://www.mcne...
# 41                    [http://www.hamptoncountry.com]
# 42  [http://www.amazon.com, http://education.ti.co...
# 43  [http://www.prudential.com, http://prudential....
# 44      [http://www.kw.com, http://www.ziprealty.com]
# 45               [http://www.online-irs-tax-help.com]
# 46  [http://www.homegain.com, http://www.relocatea...
# 47                       [http://www.howardhanna.com]
# 48                             [http://www.topix.net]
# 49  [http://www.lagumbo.com, http://reals.com, htt...

# %% [markdown]
# E.g. User 756 searched for "chesapeake real estate assesser" and "virginia beach" and at some point via search clicked on http://www.chesapeake.va.us and http://www.vbgov...

# %%
load_ready = preload(reshaped)

# peek
[print(j) for j in load_ready[0:10]]
# Out:
# {'index': {'_index': 'taste', '_id': 475}}
# {'user': 475, 'query': ['real estates lookup in charlotte', 'real estates lookup in lexington', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in winston-salem', 'real estates lookup in winston-salem', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in rural-hall', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup and phone numbers', 'real estates lookup and phone numbers', 'real estates lookup in charlotte', 'real estates lookup in winston-salem', 'real estates lookup in winston-salem', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'picture of real estates house of 6013 twin brook dr', 'picture of real estates house of 6013 twin brook dr', 'real estates lookup in winston-salem', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estates lookup in charlotte', 'real estate lookup', 'real estate lookup', 'real estate lookup', 'real estate lookup', 'real estate lookup'], 'document': ['http://meckcama.co.mecklenburg.nc.us', 'http://www.realtor.com', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://www.relo-experts.com', 'http://realestate.homes.com', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://www.neighborhoodscout.com', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://www.realestateabc.com', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://www.thedirectory.org', 'http://yp.yahoo.com', 'http://meckcama.co.mecklenburg.nc.us', 'http://www.topix.net', 'http://classifieds.mgnetwork.com', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://www.washingtonpost.com', 'http://www.washingtonpost.com', 'http://winston-salem.nc.house.info', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://www.ownthesehomes.com', 'http://www.realestateabc.com', 'http://meckcama.co.mecklenburg.nc.us', 'http://maps2.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenburg.nc.us', 'http://meckcama.co.mecklenb ...
# {'index': {'_index': 'taste', '_id': 756}}
# {'user': 756, 'query': ['chesapeake real estate assesser', 'virginia beach real estate assesser'], 'document': ['http://www.chesapeake.va.us', 'http://www.vbgov.com']}
# {'index': {'_index': 'taste', '_id': 1133}}
# {'user': 1133, 'query': ['huntsville real estate', 'huntsville real estate'], 'document': ['http://www.valleymls.com', 'http://www.valleymls.com']}
# {'index': {'_index': 'taste', '_id': 1337}}
# {'user': 1337, 'query': ['national real estate settlement services', 'national real estate settlement services', 'sunbury pennsylvania real estate settlement services', 'integrated real estate', 'integrated real estate'], 'document': ['http://www.realtms.com', 'http://dmoz.org', 'http://pa.optimuslaw.com', 'http://www.integratedreal.com', 'http://www.irisnet.net']}
# {'index': {'_index': 'taste', '_id': 1338}}
# {'user': 1338, 'query': ['real estate chesapeake appreciation 2005', 'real estate chesapeake appreciation 2005', 'real estate norfolk assessor'], 'document': ['http://realtytimes.com', 'http://realtytimes.com', 'http://www.norfolk.gov']}
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ## Load the index

# %%
create_index(index='taste', mapping_file='taste/index_definition.json')

index_mapping(index='taste')
# Out:
# Mapping for  taste
# {
#   "taste": {
#     "mappings": {
#       "properties": {
#         "document": {
#           "type": "keyword"
#         },
#         "query": {
#           "type": "text",
#           "fields": {
#             "raw": {
#               "type": "keyword"
#             },
#             "sayt": {
#               "type": "search_as_you_type",
#               "analyzer": "query_log_analyzer",
#               "max_shingle_size": 3
#             }
#           },
#           "analyzer": "query_log_analyzer"
#         },
#         "user": {
#           "type": "keyword"
#         }
#       }
#     }
#   }
# }

# %%
response = populate_index(body=load_ready)

# %% [markdown]
# ## Taste profile for one user

# %%
profile = get('10008', 'taste')

print(json.dumps(profile, indent=2))
# Out:
# {
#   "_index": "taste",
#   "_type": "_doc",
#   "_id": "10008",
#   "_version": 1,
#   "_seq_no": 15,
#   "_primary_term": 1,
#   "found": true,
#   "_source": {
#     "user": 10008,
#     "query": [
#       "cape cod real estate.com",
#       "new hampshire me real estate",
#       "new hampshire me real estate",
#       "new hampshire me real estate",
#       "nancy clayton real estate falmouth ma",
#       "nancy clayton real estate falmouth ma",
#       "nancy clayton real estate falmouth ma",
#       "nancy clayton real estate falmouth ma",
#       "new hampshire maine real estate",
#       "new hampshire maine real estate",
#       "new hampshire maine real estate",
#       "cape cod real estate associates",
#       "marcy broden era key real estate framingham ma",
#       "hudson nh real estate",
#       "salem nh real estate",
#       "salem nh real estate"
#     ],
#     "document": [
#       "http://www.capecodrealestate.com",
#       "http://www.seacoastrealestate.com",
#       "http://www.nneren.com",
#       "http://www.nneren.com",
#       "http://www.capecodrealestateonline.com",
#       "http://www.capecodrealestateonline.com",
#       "http://www.capecodrealestateonline.com",
#       "http://www.falmouth-ma.worldweb.com",
#       "http://www.seacoastonline.com",
#       "http://www.era.com",
#       "http://www.real-estate-2000.com",
#       "http://www.realestateassc.com",
#       "http://www.brodenhomes.com",
#       "http://www.harmony-re.com",
#       "http://www.homes.com",
#       "http://www.c21mclennan.com"
#     ]
#   }
# }

# %% [markdown]
# ## What other users share these interests?

# %%
peek(filename='taste/query_template.mustache')
# Out:
# {
#   "size": 0,
#   "query": {
#     "more_like_this" : {
#       "fields" : ["query", "document"],
#       "like" : [
#       {
#         "_index" : "taste",
#         "_id" : "{{user}}"
#       }
#       ],
#       "min_term_freq" : 1,
#       "max_query_terms" : 8
#     }
#   },
#   "aggs": {
#     "query_recommendations": {
#       "terms": {
#         "field": "query.raw",
#         "size": {{^size}}50{{/size}}{{size}}
#       }
#     },
#     "document_recommendations": {
#       "terms": {
#         "field": "document",
#         "size": {{^size}}50{{/size}}{{size}}
#       }
#     }
#   }
# }

# %% [markdown]
# ##  And what queries do **they** use?

# %%
# Run the query
result = query_template(index='taste', 
               template_file='taste/query_template.mustache',
               params={ 'user': '10008', 'size': 50 }
              )

# Parse the candidate queries out of the response
query_suggestion_candidates = parse_json(result, jsonpath="aggregations.query_recommendations.buckets[*].key")

# Remove the candidate queries already run by the user
query_suggestion = [s for s in query_suggestion_candidates if s not in profile['_source']['query']]

# Show
pandas.DataFrame({'Suggested Queries': query_suggestion}).head(25)
# Out:
#                                     Suggested Queries
# 0                           new hampshire real estate
# 1                                   maine real estate
# 2                              bath maine real estate
# 3                         brunswick maine real estate
# 4                          north carolina real estate
# 5                                  oregon real estate
# 6                              prudential real estate
# 7                          south carolina real estate
# 8                          united country real estate
# 9                                   98903 real estate
# 10                     affordable real estate florida
# 11                          agua dulce ca real estate
# 12                             ahoskie nc real estate
# 13               alberta banff commercial real estate
# 14                               alliance real estate
# 15                         almaden valley real estate
# 16                            amesbury ma real estate
# 17                       antique colonial real estate
# 18           antique colonial real estate sales maine
# 19                  antique real estate new hampshire
# 20                               aol real estate sale
# 21                             arco idaho real estate
# 22                       arizona real estate for sale
# 23                arizona real estate new communities
# 24  arizona real estate new communities under 200 000

# %%
# Parse the candidate documents out of the response
document_suggestion_candidates = parse_json(result, jsonpath="aggregations.document_recommendations.buckets[*].key")

# Remove the candidate documents already visited by the user
document_suggestion = [s for s in document_suggestion_candidates if s not in profile['_source']['document']]

# Show 
pandas.DataFrame({'Suggested Documents': document_suggestion}).head(25)
# Out:
#                      Suggested Documents
# 0                 http://www.realtor.com
# 1              http://www.realestate.com
# 2                http://www.homegain.com
# 3            http://realestate.yahoo.com
# 4               http://www.househunt.com
# 5               http://www.city-data.com
# 6             http://www.harmonhomes.com
# 7                http://homes.point2.com
# 8            http://www.homesandland.com
# 9         http://www.hometownlocator.com
# 10          http://www.unitedcountry.com
# 11                      http://reals.com
# 12              http://www.beangroup.com
# 13                http://www.bobvila.com
# 14                http://www.globere.com
# 15         http://www.gmacrealestate.com
# 16                http://www.loopnet.com
# 17               http://www.newhomes.com
# 18               http://www.nhliving.com
# 19         http://real-estate-agents.com
# 20                   http://valuecom.com
# 21                 http://www.4homes.com
# 22              http://www.century21.com
# 23  http://www.epoweredprofessionals.com
# 24           http://www.escapeartist.com
